# %%
#Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')   #grammar of graphics for data visualization 
from matplotlib.pyplot import figure 

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  #adjusts the configuration of the plots


#Read in the data

df = pd.read_csv(r'C:\Users\Kirby Portugaleza\OneDrive\Desktop\Pyhton Projects\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#We don't know what to do with the missing data so for now we just drop

df = df.dropna()

#Find any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Looking at the data types of columns 

df.dtypes
# Out:
# name        object
# rating      object
#             ...
# company     object
# runtime    float64
# Length: 15, dtype: object

# %%
#Changing data types of columns

df['budget'].round().astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#Partitioning strings in column released and taking the year

df['yearcorrect'] = df['released'].astype(str).str.split().str[2]
df
# Out:
#                       name     rating      genre  year  \
# 0              The Shining          R      Drama  1980
# 1          The Blue Lagoon          R  Adventure  1980
# ...                    ...        ...        ...   ...
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes         director  \
# 0         June 13, 1980 (United States)    8.4  927000.0  Stanley Kubrick
# 1          July 2, 1980 (United States)    5.8   65000.0   Randal Kleiser
# ...                                 ...    ...       ...              ...
# 7651  February 21, 2020 (United States)    6.8   42000.0    Chris Sanders
# 7652    August 28, 2020 (United States)    6.8    3700.0          Hu Guan
#
#                        writer             star         country     budget  \
# 0                Stephen King   Jack Nicholson  United Kingdom   19000000
# ...

# %%
#Sorting data by gross descending
df.sort_values(by=['gross'], inplace = True, ascending = False)
df
# Out:
#                    name rating   genre  year  \
# 5445             Avatar  PG-13  Action  2009
# 7445  Avengers: Endgame  PG-13  Action  2019
# ...                 ...    ...     ...   ...
# 272            Parasite      R  Horror  1982
# 3203         Trojan War  PG-13  Comedy  1997
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 272      March 12, 1982 (United States)    3.9     2300.0   Charles Band
# 3203           October 1, 1997 (Brazil)    5.7     5800.0   George Huang
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# ...

# %%
#Look through all the data
pd.set_option('display.max_rows', None)

#Changing it to look only through max 5
#pd.set_option('display.max_rows', 5)

# %%
#Show what values are distinct

df['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
#                        ...
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
#Scatter plot with budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show()
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
#Plot Budget vs Gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color':'red'}, line_kws = {'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Looking at correlation

correlation_matrix = df.corr(numeric_only = True)
correlation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# ...           ...       ...       ...       ...       ...       ...
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
#
# [6 rows x 6 columns]

# %%
#Create a heatmap of correlation for visualization

sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
#Including non numeric values to correlation matrix by giving numerical values to strings

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           31
# 7445  1470       47  356000000  2797501328      983    181.0           41
# ...    ...      ...        ...         ...      ...      ...          ...
# 272   1473       47     800000        2270      582     85.0            4
# 3203  1811       47   15000000         309      504     85.0           19
#
# [5421 rows x 16 columns]

# %%
df
# Out:
#                    name rating   genre  year  \
# 5445             Avatar  PG-13  Action  2009
# 7445  Avengers: Endgame  PG-13  Action  2019
# ...                 ...    ...     ...   ...
# 272            Parasite      R  Horror  1982
# 3203         Trojan War  PG-13  Comedy  1997
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 272      March 12, 1982 (United States)    3.9     2300.0   Charles Band
# 3203           October 1, 1997 (Brazil)    5.7     5800.0   George Huang
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# ...

# %%
#Create a heatmap of correlation for visualization 

correlation_matrix = df_numerized.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
#Look at highest correlation quickly

correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.026784
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
#Look at highest correlation quickly

sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
# budget       rating        -0.203946
# rating       gross         -0.181906
# gross        rating        -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# company      rating        -0.092357
# rating       company       -0.092357
# year         genre         -0.073167
# genre        year          -0.073167
# country      yearcorrect   -0.071611
# yearcorrect  country       -0.071611
# company      genre         -0.071334
# genre        company       -0.071334
# yearcorrect  genre         -0.067962
# genre        yearcorrect   -0.067962
# year         country       -0.066748
# country      year          -0.066748
# runtime      genre         -0.059237
# genre        runtime       -0.059237
# score        country       -0.043051
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr #votes and budget has the highest correlation to gross
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
#              budget         0.740247
# budget       gross          0.740247
# yearcorrect  year           0.994821
# year         yearcorrect    0.994821
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
