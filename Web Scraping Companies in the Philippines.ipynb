# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_companies_of_the_Philippines'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
soup1 = soup.find_all('table')[1]
soup1
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td><a href="/wiki/2GO" title="2GO">2GO</a>
# </td>
# <td>Industrials
# </td>
# <td>Marine transportation
# </td>
# <td><a href="/wiki/Manila" title="Manila">Manila</a>
# </td>
# <td>2012
# </td>
# <td>Shipping, part of <a href="/wiki/2GO_Group" title="2GO Group">2GO Group</a>
# ...

# %%
column_names = soup1.find_all('th')
column_names = [title.text.strip() for title in column_names]
column_names
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
import pandas as pd

df = pd.DataFrame(columns = column_names)
df
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Sector, Headquarters, Founded, Notes]
# Index: []

# %%
column_data = soup1.find_all('tr')
#column_data
for row in column_data[1:]: 
    row_data = row.find_all('td')
    row_data = [data.text.strip() for data in row_data]

    length = len(df) #checks the row length of df which starts at 0 for column names 
    df.loc[length] = row_data
df
# Out:
#                          Name           Industry  \
# 0                         2GO        Industrials
# 1         2GO (cargo airline)        Industrials
# 2                   2GO Group        Industrials
# 3     Aboitiz Equity Ventures      Conglomerates
# 4         ABS-CBN Corporation       Conglomerate
# ..                        ...                ...
# 505                  Upstream  Consumer services
# 506       Viva Communications  Consumer services
# 507                Viva Films  Consumer services
# 508        Zest-O Corporation     Consumer goods
# 509  ZOE Broadcasting Network  Consumer services
#
#                               Sector Headquarters Founded  \
# 0              Marine transportation       Manila    2012
# 1                  Delivery services       Manila    1988
# 2                  Delivery services       Manila    1949
# 3                                  -         Cebu    1989
# 4            Media and entertainment  Quezon City    1946
# ...

# %%
df.to_csv(r'')
